# %%
import numpy as np
from collections import Counter

# %%
def getdata(filename):
    items=[]
    label=[]
    with open(filename,'r') as f:
        for item in f.readlines():
            itemrow=item.replace('\n','').split('\t')
            items.append(itemrow[:3])
            label.append(itemrow[-1])
    data=np.array(items)
    label=np.array(label)
    return data.astype(float),label

# %%
#数值归一化，特征缩放
def tonorm(dataset):
    for col in range(dataset.shape[1]):
        maxnum=dataset[:,col].max()
        minnum=dataset[:,col].min()
        s=maxnum-minnum
        dataset[:,col]=(dataset[:,col]-minnum)/s
    return dataset
# Out:
# array([[0.448325, 0.398051, 0.562334],
#        [0.158733, 0.341955, 0.987244],
#        [0.285429, 0.068925, 0.474496],
#        ...,
#        [0.291159, 0.509103, 0.510795],
#        [0.527111, 0.436655, 0.429005],
#        [0.479408, 0.376809, 0.785718]])

# %%
#knn关键算法
#dataset:训练数据集;label:标签;traindata:测试数据
def knn(k,dataset,label,traindata):
#     traindata=np.array(traindata)
#     dataset=np.array(dataset)
#     label=np.array(label)
    label=label.reshape(len(label),1)
    dl=np.append(dataset,label,axis=1)
    result=[]
    for cr_data in traindata:
        #计算距离
        ret=np.sum((cr_data-dataset)**2,axis=1)
        ret1=np.sqrt(ret).reshape(len(ret),1)
        #拼接数组，按距离排序
        x=np.append(dl,ret1,axis=1)
        ret2=x[np.lexsort(ret1.T)] #对ret1进行排序取索引(数组值从小到大的索引值)
        #取前k个
        retk=ret2[0:k,]
        predict=Counter(retk[:,-2]).most_common(1)
        r_row=list(cr_data)
        r_row.append(predict[0][0])
        result.append(r_row)
    return result

# test=[[101,20]]
# #初始化
# group=[[1,101],[5,89],[108,5],[115,8]]
# label=['爱情片','爱情片','动作片','动作片']
# knn(3,group,label,test)
# Out:
# [[101, 20, '动作片']]

# %%
def datatest(filename,radio):
    #radio做测试，1-radio做训练数据
    #取数据
    dataset,label=getdata(filename)
    #数值归一化
    dataset=tonorm(dataset)
    #取行数，分类数据数量
    rowtotal=dataset.shape[0]

    testnum=int(rowtotal*radio)
    trainnum=int(rowtotal-testnum)
    testdata=dataset[0:testnum,:]
    testlabel=label[0:testnum]

    traindata=dataset[testnum:trainnum,:]
    trainlabel=label[testnum:trainnum]
    #预测数据
    predicts=knn(4,traindata,trainlabel,testdata)
    #计算错误率
    errnum=0
    for item,tlabel in zip(predicts,testlabel):
        if item[-1]!=tlabel:
            errnum+=1
    
    print('错误率:',errnum/testnum*100,'%')
    
filename=r'C:\Users\Administrator\Desktop\ML_project\Machine-Learning-master\kNN\datingTestSet.txt'
radio=0.1
datatest(filename,radio)
# Out:
# [0.44832535360950115, 0.39805139251704247, 0.562333528687216, 'largeDoses'] largeDoses
# [0.15873259342850568, 0.3419546659888891, 0.9872441587123406, 'smallDoses'] smallDoses
# [0.2854294260076912, 0.06892523280719681, 0.47449628503016766, 'didntLike'] didntLike
# [0.7889627819837192, 0.23580925008708445, 0.3723350572870834, 'didntLike'] didntLike
# [0.06479462710768792, 0.10594239811191065, 0.345817095648448, 'smallDoses'] smallDoses
# [0.1627096731782674, 0.6838470929472996, 0.3725068034497961, 'largeDoses'] largeDoses
# [0.3676114513602051, 0.6019254710077259, 0.4045330363482162, 'largeDoses'] largeDoses
# [0.49250052041677167, 0.16370724538320958, 0.5921689651733014, 'didntLike'] didntLike
# [0.19648746069483855, 0.0, 0.0864142883364289, 'smallDoses'] smallDoses
# [0.30390148236608855, 0.4079392241125668, 0.12049852422240598, 'largeDoses'] largeDoses
# [0.32090541562126806, 0.46987733700508555, 0.14014959031752974, 'largeDoses'] largeDoses
# [0.46377351462097227, 0.549356770136585, 0.15483300193996438, 'largeDoses'] largeDoses
# [0.3991213173665816, 0.17070167910100836, 0.49050822109337977, 'didntLike'] didntLike
# [0.43411523670746005, 0.08466936518913662, 0.12184888580414681, 'didntLike'] didntLike
# [0.35502284355724034, 0.16797468219493827, 0.5847030237357919, 'didntLike'] didntLike
# [0.2987520953622649, 0.2102442097983068, 0.5747700755624097, 'didntLike'] didntLike
# [0.06000679280838802, 0.20444340787086634, 0.6927201464150792, 'smallDoses'] smallDoses
# [0.15616885606915518, 0.2842351356153578, 0.9520332443912485, 'smallDoses'] smallDoses
# [0.75173380956033, 0.6596271231958509, 0.4268387905528987, 'didntLike'] didntLike
# [0.45510720585496256, 0.4968410345847761, 0.9812359939823923, 'largeDoses'] largeDoses
# [0.08673978065802593, 0.1437701048918874, 0.17478329588558755, 'smallDoses'] smallDoses
# [0.2337054769756664, 0.04932935532554096, 0.2862542279950967, 'smallDoses'] smallDoses
# [0.0913523166763446, 0.2271204519796481, 0.03749909257826402, 'smallDoses'] smallDoses
# [0.056708993897428596, 0.17650018650197957, 0.9761538420678947, 'smallDoses'] smallDoses
# [0.20798045424167058, 0.4994462781800715, 0.15728407346486376, 'largeDoses'] largeDoses
# [0.7541879854940673, 0.5060284619755615, 0.1938199710687392, 'didntLike'] didntLike
# [0.14722864373911235, 0.07669937530082795, 0.04007882617694812, 'smallDoses'] smallDoses
# [0.535196607978263, 0.1758896512506197, 0.5667682388817967, 'didntLike'] didntLike
# [0.1345962113659023, 0.18141797815983662, 0.4105016581472307, 'smallDoses'] smallDoses
# [0.08574277168494517, 0.12103077394999241, 0.9785500256438858, 'smallDoses'] smallDoses
# [0.0609709333537848, 0.4652792971712456, 0.576376580905722, 'smallDoses'] smallDoses
# [0.11335225093948922, 0.2912646564670822, 0.8337314185111674, 'smallDoses'] smallDoses
# [0.019973047889299135, 0.3686998099223833, 0.621928266762514, 'smallDoses'] smallDoses
# [0.10675665311757036, 0.5483136210405017, 0.44813649511526765, 'largeDoses'] largeDoses
# [0.18468769515628938, 0.13798369155751453, 0.5508035182585057, 'smallDoses'] smallDoses
# [0.4309708237923592, 0.48062552042130946, 0.6711645275121417, 'largeDoses'] largeDoses
# [0.7146691792753608, 0.4767103412252455, 0.5197947780903833, 'didntLike'] didntLike
# [0.02698497912854842, 0.11165667727040646, 0.8056069515292196, 'smallDoses'] smallDoses
# [0.29968336747997765, 0.5437623799861075, 0.901502100201787, 'largeDoses'] largeDoses
# [0.1773909042104456, 0.0, 0.3567498307621575, 'smallDoses'] smallDoses
# [0.13430039551674647, 0.19727129175960495, 0.2103123242331475, 'smallDoses'] smallDoses
# [0.4642884533213546, 0.30208980212529557, 0.6240972260338854, 'largeDoses'] didntLike
# [0.28055394256790067, 0.4149520618447543, 0.050637969122282675, 'largeDoses'] largeDoses
# [0.8485532413747767, 0.7101746330633902, 0.6661313616165623, 'didntLike'] didntLike
# [0.6434761649118579, 0.11732128949136993, 0.130564856013565, 'didntLike'] didntLike
# [0.5086498745521677, 0.3485864689192766, 0.32310174750245074, 'largeDoses'] largeDoses
# [0.35813438804465725, 0.4180405900776358, 0.5053185242106021, 'largeDoses'] largeDoses
# [0.7109440908045096, 0.41009885154647974, 0.40244788448270463, 'didntLike'] didntLike
# [0.09371884346959122, 0.11985564177929246, 0.5122999171959222, 'smallDoses'] smallDoses
# [0.3162052304624588, 0.5456898300229133, 0.887833230344655, 'largeDoses'] largeDoses
# [0.4607057947038007, 0.23129496046937215, 0.9913684273894406, 'largeDoses'] didntLike
# [0.35271109747680035, 0.4942556768855474, 0.3437815199948535, 'largeDoses'] largeDoses
# [0.7109988715173162, 0.31424218793806635, 0.6788854323252247, 'didntLike'] didntLike
# [0.025801715731925103, 0.31260040644668247, 0.2720252649819017, 'smallDoses'] smallDoses
# [0.0, 0.10560362083925269, 0.42636191460969647, 'smallDoses'] smallDoses
# [0.7713781731727893, 0.5352163683487473, 0.4929114869853591, 'didntLike'] didntLike
# [0.6288716268776089, 0.20218578503566242, 0.07501175959550534, 'didntLike'] didntLike
# [0.4572217413692987, 0.45440916923370794, 0.0024298245769349036, 'largeDoses'] largeDoses
# [0.12521775333340637, 0.41362305299271024, 0.7954491398232136, 'smallDoses'] largeDoses
# [0.8246688505910839, 0.8174780199900102, 0.28893252382461587, 'didntLike'] didntLike
# [0.05980958224228414, 0.3762946447329694, 0.42287682495052703, 'smallDoses'] smallDoses
# [0.8054956011087616, 0.3949516306649887, 0.8029516732266618, 'didntLike'] didntLike
# [0.44130246622769054, 0.43097110717929127, 0.9781852863704961, 'largeDoses'] largeDoses
# [0.23599531077098376, 0.44051805818622747, 0.47546302116255035, 'largeDoses'] largeDoses
# [0.1938579864801201, 0.30474213131584543, 0.01919425671388801, 'smallDoses'] smallDoses
# [0.24463970725187076, 0.10813022910034151, 0.6025947245008592, 'didntLike'] didntLike
# [0.5102275590809988, 0.27138081591353536, 0.41804137370961675, 'didntLike'] didntLike
# 错误率: 3.0 %
